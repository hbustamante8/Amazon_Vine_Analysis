# %%
import pandas as pd
import csv

# %%
vine_df = pd.read_csv("vine_table.csv")

# %%
vine_df.tail(30)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 4864219  R15GVWRTHQURK4          5.0           58.0         60.0    N
# 4864220   RX4TNMHCHDXF5          5.0            2.0          2.0    N
# 4864221  R281Y9SN6SMR9L          5.0           12.0         14.0    N
# 4864222   RR1PBRYLQHDN0          5.0           15.0         17.0    N
# 4864223  R39HOOA1RU1Q44          5.0            2.0          2.0    N
# 4864224  R2A8FINE8TXEA4          5.0           35.0         35.0    N
# 4864225    RG6J6CBLLH4F          5.0            5.0         18.0    N
# 4864226  R2GLKH27M7DT3F          5.0           26.0         27.0    N
# 4864227  R1CZH1TIY8Q3TI          5.0            0.0          0.0    N
# 4864228  R22O58NKQZPC6R          3.0            3.0          3.0    N
# 4864229  R18ZLUQY7Z1O1A          1.0           22.0         26.0    N
# 4864230    R9P58SVTC6WX          3.0           29.0         34.0    N
# ...

# %%
#Filter the new DataFrame or table created in Step 1 and create a new DataFrame or table to retrieve all the rows where the number of helpful_votes divided by total_vote
vine_df_reviews = vine_df[vine_df["total_votes"]>= 20]

# %%
vine_df_reviews = vine_df_reviews[vine_df_reviews["helpful_votes"] >= 50 ]

# %%
# Filter the dataframe that retrieves all the rows where a review was written as part of the vine program(paid)
vine_df_reviews_vine = vine_df_reviews[vine_df_reviews["vine"] == "Y"]

# %%
vine_df_reviews_vine.head()
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 25013  R1V8NDXD9SETO5          3.0          320.0        352.0    Y
# 33963  R34JSTH01HK1J8          4.0           75.0         80.0    Y
# 42867  R24STRS5M3QEXQ          5.0           60.0         65.0    Y
# 46291  R1NMYF3BJM72A0          4.0           57.0         60.0    Y
# 75128   RE9U5PTH7RV14          5.0          173.0        188.0    Y
#
#       verified_purchase
# 25013                 N
# 33963                 N
# 42867                 N
# 46291                 N
# 75128                 N

# %%
vine_df_reviews_novine = vine_df_reviews[vine_df_reviews["vine"] == "N"]

# %%
vine_df_reviews_novine.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 424   R1QS8AOD6HX3ED          4.0           59.0         81.0    N
# 1176  R2LWX4TZ67FWPT          4.0           50.0         50.0    N
# 1515  R29IYHPYD14AGI          3.0           84.0         84.0    N
# 4145  R18T8SFBDXAKSY          5.0           95.0         95.0    N
# 4252  R36SKVJXZ0I98A          5.0          124.0        127.0    N
#
#      verified_purchase
# 424                  N
# 1176                 N
# 1515                 Y
# 4145                 Y
# 4252                 N

# %%
# total number of vine count reviews
vine_paid_count = vine_df_reviews_vine["review_id"].count()
vine_yes_count
# Out:
# 381

# %%
vine_nopaid_count = vine_df_reviews_novine["review_id"].count()
vine_no_count
# Out:
# 14507

# %%
total_reviews_count = vine_df_reviews_vine["review_id"].count() + vine_df_reviews_novine["review_id"].count()
total_reviews_count
# Out:
# 14888

# %%
vine_paid_review_percentage = vine_paid_count/total_reviews_count * 100
vine_paid_review_percentage
# Out:
# 2.559108006448146

# %%
vine_nopaid_review_percentage = vine_nopaid_count/total_reviews_count * 100
vine_nopaid_review_percentage
# Out:
# 97.44089199355186
